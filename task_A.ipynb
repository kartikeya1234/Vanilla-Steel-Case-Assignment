# %% [markdown]
# # Scenario A

# %%
# Importing the necessary libraries

import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Loading the datasets

supplier_data_1 = pd.read_excel('./data/supplier_data1.xlsx')
supplier_data_2 = pd.read_excel('./data/supplier_data2.xlsx')

# %%
# Checking for missing values in supplier_data_1

supplier_data_1.isna().sum()
# Out:
# Quality/Choice       0
# Grade                0
# Finish               0
# Thickness (mm)       0
# Width (mm)           0
# Description          0
# Gross weight (kg)    0
# RP02                 0
# RM                   0
# Quantity             0
# AG                   0
# AI                   0
# dtype: int64

# %% [markdown]
# ### Task A.1

# %% [markdown]
# - Cleaning and normailizing both datasets.

# %%
# Renaming columns in supplier_data_1 for consistency

rename_cols_supplier_data_1 = {
    "Quality/Choice": "Quality",
    "Thickness (mm)": "Thickness_mm",
    "Width (mm)": "Width_mm",
    "Gross weight (kg)": "Weight_kg",
}

# %%
supplier_data_1.rename(columns=rename_cols_supplier_data_1, inplace=True)

# %%
supplier_data_1.head()
# Out:
#   Quality  Grade               Finish  Thickness_mm  Width_mm  \
# 0     3rd  C200S  gebeizt und geglüht          2.77      1100
# 1     3rd  C300S            ungebeizt          2.65      1075
# 2     3rd  C100S  gebeizt und geglüht          2.20      1100
# 3     2nd  C100S              gebeizt          2.86      1100
# 4     1st  C300S            ungebeizt          2.88      1050
#
#                           Description  Weight_kg   RP02      RM  Quantity  \
# 0                Längs- oder Querisse      13983  333.6   606.2      0.00
# 1                Längs- oder Querisse      13047  717.7     0.0      0.00
# 2       Kantenfehler - FS-Kantenrisse      14155  368.9     0.0     10.84
# 3                Längs- oder Querisse      11381  368.9   601.7     22.87
# 4  Sollmasse (Gewicht) unterschritten      10072    0.0  1213.0     22.87
#
#       AG      AI
# 0  16.11  0.0054
# 1  16.11  0.0046
# 2   0.00  0.0061
# 3   0.00  0.0062
# 4   0.00  0.0041

# %%
# Descriptive statistics of supplier_data_1

supplier_data_1.describe()
# Out:
#        Thickness_mm     Width_mm     Weight_kg       RP02           RM  \
# count     50.000000    50.000000     50.000000   50.00000    50.000000
# mean       2.508800  1075.000000  10227.840000  336.39200   653.682000
# std        0.273112    48.968961   2900.401516  245.12073   403.594141
# min        2.010000  1000.000000   5011.000000    0.00000     0.000000
# 25%        2.292500  1050.000000   8065.500000   83.40000   601.700000
# 50%        2.510000  1075.000000  10167.000000  368.90000   606.200000
# 75%        2.750000  1100.000000  12844.000000  368.90000  1061.300000
# max        2.980000  1150.000000  14839.000000  717.70000  1213.000000
#
#         Quantity         AG         AI
# count  50.000000  50.000000  50.000000
# mean   13.536200   9.706120   0.005500
# std    10.380396   7.080155   0.000886
# min     0.000000   0.000000   0.004100
# 25%     0.000000   0.000000   0.004725
# 50%    10.840000  15.050000   0.005450
# 75%    22.870000  16.110000   0.006200
# max    25.460000  16.110000   0.007000

# %%
# Standardizing numerical columns in supplier_data_1

supplier_data_1 = supplier_data_1.apply(
    lambda x: StandardScaler().fit_transform(x.values.reshape(-1, 1)).flatten() 
    if x.dtype != "object" else x
)

# %%
supplier_data_1
# Out:
#    Quality  Grade               Finish  Thickness_mm  Width_mm  \
# 0      3rd  C200S  gebeizt und geglüht      0.966093  0.515711
# 1      3rd  C300S            ungebeizt      0.522252  0.000000
# 2      3rd  C100S  gebeizt und geglüht     -1.142149  0.515711
# 3      2nd  C100S              gebeizt      1.298973  0.515711
# 4      1st  C300S            ungebeizt      1.372946 -0.515711
# 5      2nd  C200S              gebeizt      0.004438 -1.547132
# 6      1st  C100S              gebeizt      0.670199  1.547132
# 7      2nd  C300S  gebeizt und geglüht      1.742813 -1.547132
# 8      3rd  C200S              gebeizt     -1.770923 -0.515711
# 9      3rd  C300S              gebeizt      0.115399 -0.515711
# 10     2nd  C100S  gebeizt und geglüht     -0.735296 -0.515711
# 11     1st  C100S            ungebeizt      0.152385 -0.515711
# 12     3rd  C100S  gebeizt und geglüht      0.041425  0.515711
# 13     2nd  C200S            ungebeizt     -0.180495 -1.547132
# 14     3rd  C100S  gebeizt und geglüht      0.855133  0.515711
# 15     2nd  C100S              gebeizt     -0.883242  1.547132
# 16     2nd  C300S            ungebeizt     -1.585990  1.547132
# 17     1st  C300S  gebeizt und geglüht     -0.809269 -0.515711
# 18     3rd  C100S            ungebeizt     -1.179136 -0.515711
# 19     2nd  C100S  gebeizt und geglüht     -1.364070 -1.547132
# 20     1st  C100S              gebeizt      1.225000  1.547132
# 21     2nd  C200S  gebeizt und geglüht      1.372946 -0.515711
# 22     1st  C100S  gebeizt und geglüht      0.004438 -0.515711
# 23     3rd  C200S              gebeizt     -1.068176 -0.515711
# 24     2nd  C200S            ungebeizt      1.188013  0.515711
# 25     3rd  C300S              gebeizt     -0.698309  1.547132
# 26     3rd  C100S  gebeizt und geglüht     -0.106522 -0.515711
# 27     2nd  C300S  gebeizt und geglüht     -1.105163  0.515711
# 28     2nd  C100S            ungebeizt      0.892119  0.515711
# 29     3rd  C200S              gebeizt      0.892119  0.000000
# 30     3rd  C100S            ungebeizt      1.409933  0.000000
# 31     1st  C100S  gebeizt und geglüht     -0.698309  1.547132
# 32     3rd  C300S              gebeizt      0.078412  0.515711
# 33     2nd  C100S  gebeizt und geglüht     -1.216123  0.000000
# 34     2nd  C100S              gebeizt      0.892119 -1.547132
# 35     2nd  C300S            ungebeizt     -0.291455 -1.547132
# 36     1st  C300S              gebeizt      1.151026 -0.515711
# 37     1st  C200S  gebeizt und geglüht      1.077053 -0.515711
# 38     1st  C100S              gebeizt     -1.844897 -0.515711
# 39     2nd  C300S            ungebeizt     -0.772282 -1.547132
# 40     3rd  C200S            ungebeizt     -1.438043  0.000000
# 41     1st  C100S  gebeizt und geglüht     -0.513375  0.000000
# 42     2nd  C100S  gebeizt und geglüht     -0.291455  1.547132
# 43     3rd  C100S            ungebeizt     -1.585990  0.515711
# 44     3rd  C100S  gebeizt und geglüht      0.892119 -0.515711
# 45     2nd  C300S            ungebeizt      0.781159  1.547132
# 46     3rd  C100S  gebeizt und geglüht      0.855133 -1.547132
# 47     3rd  C100S              gebeizt     -0.106522  1.547132
# 48     1st  C300S              gebeizt     -0.106522  1.547132
# 49     1st  C100S              gebeizt      1.040066 -0.515711
#
#                            Description  Weight_kg      RP02        RM  \
# 0                 Längs- oder Querisse   1.307848 -0.011506 -0.118842
# 1                 Längs- oder Querisse   0.981858  1.571386 -1.636095
# 2        Kantenfehler - FS-Kantenrisse   1.367752  0.133967 -1.636095
# 3                 Längs- oder Querisse   0.401623  0.133967 -0.130105
# 4   Sollmasse (Gewicht) unterschritten  -0.054276 -1.386285  1.399913
# 5                 Längs- oder Querisse   0.917774 -1.386285 -0.118842
# 6   Sollmasse (Gewicht) unterschritten  -0.449922 -1.386285 -0.118842
# 7   Sollmasse (Gewicht) unterschritten  -0.145525 -1.386285 -0.130105
# 8                 Längs- oder Querisse  -1.649748  0.133967 -0.130105
# 9                 Längs- oder Querisse   0.413464  0.133967 -0.118842
# 10       Kantenfehler - FS-Kantenrisse   1.577765 -0.011506 -1.636095
# 11  Sollmasse (Gewicht) unterschritten   1.104801  1.571386 -0.118842
# 12                Längs- oder Querisse   0.891305  0.133967 -1.636095
# 13  Sollmasse (Gewicht) unterschritten  -0.639735  0.133967 -0.130105
# 14                Längs- oder Querisse   0.063094 -1.386285 -0.130105
# 15  Sollmasse (Gewicht) unterschritten  -1.489539 -1.386285 -0.130105
# 16       Kantenfehler - FS-Kantenrisse  -0.692325 -0.011506 -0.130105
# 17                Längs- oder Querisse   1.362180  0.133967 -0.118842
# 18                Längs- oder Querisse  -1.018316 -0.011506  1.399913
# 19       Kantenfehler - FS-Kantenrisse   1.145898  0.133967  1.399913
# 20                Längs- oder Querisse   0.620691  1.571386  1.399913
# 21  Sollmasse (Gewicht) unterschritten  -1.240867  1.571386  1.399913
# 22                Längs- oder Querisse   1.605976 -1.386285 -0.118842
# 23                Längs- oder Querisse   0.254649  0.133967 -0.118842
# 24  Sollmasse (Gewicht) unterschritten   1.553386 -0.011506 -0.118842
# 25                Längs- oder Querisse  -1.479787  1.571386 -0.130105
# 26       Kantenfehler - FS-Kantenrisse   0.094440 -0.011506  1.399913
# 27  Sollmasse (Gewicht) unterschritten   0.172454  0.133967  1.399913
# 28                Längs- oder Querisse   0.011897  0.133967 -1.636095
# 29       Kantenfehler - FS-Kantenrisse  -0.734816 -1.386285 -0.130105
# 30  Sollmasse (Gewicht) unterschritten  -1.816922 -1.386285 -0.118842
# 31  Sollmasse (Gewicht) unterschritten  -0.633118 -0.011506 -0.130105
# 32                Längs- oder Querisse  -1.777567 -1.386285 -0.130105
# 33  Sollmasse (Gewicht) unterschritten   0.641936  0.133967  1.399913
# 34       Kantenfehler - FS-Kantenrisse   1.077287  0.133967 -0.118842
# 35                Längs- oder Querisse  -0.787058  1.571386  1.399913
# 36       Kantenfehler - FS-Kantenrisse   0.861701  1.571386 -1.636095
# 37       Kantenfehler - FS-Kantenrisse  -1.502077  1.571386 -0.130105
# 38                Längs- oder Querisse  -0.759543 -0.011506 -0.130105
# 39                Längs- oder Querisse  -0.855321 -1.386285 -1.636095
# 40                Längs- oder Querisse  -0.081094  0.133967 -1.636095
# 41       Kantenfehler - FS-Kantenrisse  -0.158064  0.133967 -0.118842
# 42  Sollmasse (Gewicht) unterschritten   0.394309  0.133967 -0.118842
# 43                Längs- oder Querisse  -0.685012 -0.011506  1.399913
# 44       Kantenfehler - FS-Kantenrisse  -0.389322  0.133967  1.399913
# 45                Längs- oder Querisse   1.197791 -1.386285 -0.118842
# 46                Längs- oder Querisse  -1.142652  1.571386 -0.118842
# 47  Sollmasse (Gewicht) unterschritten  -0.502164  1.571386  1.399913
# 48  Sollmasse (Gewicht) unterschritten   1.422084  0.133967  1.399913
# 49  Sollmasse (Gewicht) unterschritten  -0.759195 -1.386285 -1.636095
#
#     Quantity        AG        AI
# 0  -1.317255  0.913666 -0.113961
# 1  -1.317255  0.913666 -1.025645
# 2  -0.262377 -1.384809  0.683763
# 3   0.908305 -1.384809  0.797724
# 4   0.908305 -1.384809 -1.595448
# 5  -1.317255 -1.384809  0.455842
# 6  -0.262377  0.762432  1.253566
# 7   0.908305  0.762432 -1.481487
# 8   0.908305 -1.384809  1.025645
# 9  -1.317255  0.762432  1.367527
# 10 -1.317255 -1.384809  0.683763
# 11 -1.317255  0.762432 -0.911685
# 12  1.160347  0.913666 -0.569803
# 13  0.908305 -1.384809 -0.227921
# 14 -0.262377 -0.406352  0.797724
# 15 -1.317255 -0.406352  0.683763
# 16  0.908305  0.762432  1.481487
# 17  0.908305  0.913666  1.253566
# 18 -0.262377 -1.384809  1.025645
# 19  0.908305  0.913666  0.000000
# 20 -0.262377 -0.406352  1.481487
# 21 -1.317255  0.913666 -0.455842
# 22 -1.317255  0.762432 -1.595448
# 23  0.908305 -1.384809 -0.455842
# 24 -1.317255  0.913666  0.227921
# 25  1.160347  0.913666  1.139606
# 26 -0.262377  0.762432  0.455842
# 27  1.160347 -0.406352 -1.481487
# 28 -0.262377 -0.406352 -0.683763
# 29 -1.317255 -1.384809  1.595448
# 30 -0.262377 -1.384809 -0.227921
# 31  1.160347 -0.406352 -0.797724
# 32  1.160347  0.762432 -1.595448
# 33  1.160347  0.913666 -0.113961
# 34 -0.262377  0.913666 -1.139606
# 35 -1.317255 -1.384809 -0.911685
# 36  0.908305  0.913666 -0.113961
# 37 -1.317255  0.762432  0.341882
# 38  0.908305  0.913666  1.367527
# 39  1.160347 -1.384809  0.455842
# 40 -0.262377  0.762432  1.709409
# 41 -0.262377  0.913666  0.911685
# 42  0.908305  0.913666 -0.455842
# 43  0.908305  0.762432 -1.595448
# 44  0.908305  0.913666  0.341882
# 45 -0.262377 -1.384809  0.000000
# 46  0.908305 -0.406352 -1.139606
# 47 -1.317255 -1.384809 -1.481487
# 48  1.160347  0.762432 -1.025645
# 49 -1.317255  0.762432 -0.341882

# %%
# Checking the frequency of each unique value in the 'Description' column

supplier_data_1['Description'].value_counts()
# Out:
# Description
# Längs- oder Querisse                  23
# Sollmasse (Gewicht) unterschritten    16
# Kantenfehler - FS-Kantenrisse         11
# Name: count, dtype: int64

# %%
# Mappings for translations from German to English for supplier_data_1 columns - description and finish

description_mapping_supplier_1_data = {
    "Längs- oder Querisse": "Longitudinal or transverse seams",
    "Sollmasse (Gewicht) unterschritten": "Tare weight (weight) exceeded",
    "Kantenfehler - FS-Kantenrisse": "Edge defects - edge cracks, FS"
}

finish_mapping_supplier_1_data = {
    "gebeizt und geglüht": "seasoned and annealed",
    "gebeizt": "stained",
    "ungebeizt": "unstained"
}

# %%
supplier_data_1['Description'] = supplier_data_1['Description'].apply(lambda x: description_mapping_supplier_1_data.get(x, x))
supplier_data_1['Finish'] = supplier_data_1['Finish'].apply(lambda x: finish_mapping_supplier_1_data.get(x, x))

# %%
supplier_data_1
# Out:
#    Quality  Grade                 Finish  Thickness_mm  Width_mm  \
# 0      3rd  C200S  seasoned and annealed      0.966093  0.515711
# 1      3rd  C300S              unstained      0.522252  0.000000
# 2      3rd  C100S  seasoned and annealed     -1.142149  0.515711
# 3      2nd  C100S                stained      1.298973  0.515711
# 4      1st  C300S              unstained      1.372946 -0.515711
# 5      2nd  C200S                stained      0.004438 -1.547132
# 6      1st  C100S                stained      0.670199  1.547132
# 7      2nd  C300S  seasoned and annealed      1.742813 -1.547132
# 8      3rd  C200S                stained     -1.770923 -0.515711
# 9      3rd  C300S                stained      0.115399 -0.515711
# 10     2nd  C100S  seasoned and annealed     -0.735296 -0.515711
# 11     1st  C100S              unstained      0.152385 -0.515711
# 12     3rd  C100S  seasoned and annealed      0.041425  0.515711
# 13     2nd  C200S              unstained     -0.180495 -1.547132
# 14     3rd  C100S  seasoned and annealed      0.855133  0.515711
# 15     2nd  C100S                stained     -0.883242  1.547132
# 16     2nd  C300S              unstained     -1.585990  1.547132
# 17     1st  C300S  seasoned and annealed     -0.809269 -0.515711
# 18     3rd  C100S              unstained     -1.179136 -0.515711
# 19     2nd  C100S  seasoned and annealed     -1.364070 -1.547132
# 20     1st  C100S                stained      1.225000  1.547132
# 21     2nd  C200S  seasoned and annealed      1.372946 -0.515711
# 22     1st  C100S  seasoned and annealed      0.004438 -0.515711
# 23     3rd  C200S                stained     -1.068176 -0.515711
# 24     2nd  C200S              unstained      1.188013  0.515711
# 25     3rd  C300S                stained     -0.698309  1.547132
# 26     3rd  C100S  seasoned and annealed     -0.106522 -0.515711
# 27     2nd  C300S  seasoned and annealed     -1.105163  0.515711
# 28     2nd  C100S              unstained      0.892119  0.515711
# 29     3rd  C200S                stained      0.892119  0.000000
# 30     3rd  C100S              unstained      1.409933  0.000000
# 31     1st  C100S  seasoned and annealed     -0.698309  1.547132
# 32     3rd  C300S                stained      0.078412  0.515711
# 33     2nd  C100S  seasoned and annealed     -1.216123  0.000000
# 34     2nd  C100S                stained      0.892119 -1.547132
# 35     2nd  C300S              unstained     -0.291455 -1.547132
# 36     1st  C300S                stained      1.151026 -0.515711
# 37     1st  C200S  seasoned and annealed      1.077053 -0.515711
# 38     1st  C100S                stained     -1.844897 -0.515711
# 39     2nd  C300S              unstained     -0.772282 -1.547132
# 40     3rd  C200S              unstained     -1.438043  0.000000
# 41     1st  C100S  seasoned and annealed     -0.513375  0.000000
# 42     2nd  C100S  seasoned and annealed     -0.291455  1.547132
# 43     3rd  C100S              unstained     -1.585990  0.515711
# 44     3rd  C100S  seasoned and annealed      0.892119 -0.515711
# 45     2nd  C300S              unstained      0.781159  1.547132
# 46     3rd  C100S  seasoned and annealed      0.855133 -1.547132
# 47     3rd  C100S                stained     -0.106522  1.547132
# 48     1st  C300S                stained     -0.106522  1.547132
# 49     1st  C100S                stained      1.040066 -0.515711
#
#                          Description  Weight_kg      RP02        RM  Quantity  \
# 0   Longitudinal or transverse seams   1.307848 -0.011506 -0.118842 -1.317255
# 1   Longitudinal or transverse seams   0.981858  1.571386 -1.636095 -1.317255
# 2     Edge defects - edge cracks, FS   1.367752  0.133967 -1.636095 -0.262377
# 3   Longitudinal or transverse seams   0.401623  0.133967 -0.130105  0.908305
# 4      Tare weight (weight) exceeded  -0.054276 -1.386285  1.399913  0.908305
# 5   Longitudinal or transverse seams   0.917774 -1.386285 -0.118842 -1.317255
# 6      Tare weight (weight) exceeded  -0.449922 -1.386285 -0.118842 -0.262377
# 7      Tare weight (weight) exceeded  -0.145525 -1.386285 -0.130105  0.908305
# 8   Longitudinal or transverse seams  -1.649748  0.133967 -0.130105  0.908305
# 9   Longitudinal or transverse seams   0.413464  0.133967 -0.118842 -1.317255
# 10    Edge defects - edge cracks, FS   1.577765 -0.011506 -1.636095 -1.317255
# 11     Tare weight (weight) exceeded   1.104801  1.571386 -0.118842 -1.317255
# 12  Longitudinal or transverse seams   0.891305  0.133967 -1.636095  1.160347
# 13     Tare weight (weight) exceeded  -0.639735  0.133967 -0.130105  0.908305
# 14  Longitudinal or transverse seams   0.063094 -1.386285 -0.130105 -0.262377
# 15     Tare weight (weight) exceeded  -1.489539 -1.386285 -0.130105 -1.317255
# 16    Edge defects - edge cracks, FS  -0.692325 -0.011506 -0.130105  0.908305
# 17  Longitudinal or transverse seams   1.362180  0.133967 -0.118842  0.908305
# 18  Longitudinal or transverse seams  -1.018316 -0.011506  1.399913 -0.262377
# 19    Edge defects - edge cracks, FS   1.145898  0.133967  1.399913  0.908305
# 20  Longitudinal or transverse seams   0.620691  1.571386  1.399913 -0.262377
# 21     Tare weight (weight) exceeded  -1.240867  1.571386  1.399913 -1.317255
# 22  Longitudinal or transverse seams   1.605976 -1.386285 -0.118842 -1.317255
# 23  Longitudinal or transverse seams   0.254649  0.133967 -0.118842  0.908305
# 24     Tare weight (weight) exceeded   1.553386 -0.011506 -0.118842 -1.317255
# 25  Longitudinal or transverse seams  -1.479787  1.571386 -0.130105  1.160347
# 26    Edge defects - edge cracks, FS   0.094440 -0.011506  1.399913 -0.262377
# 27     Tare weight (weight) exceeded   0.172454  0.133967  1.399913  1.160347
# 28  Longitudinal or transverse seams   0.011897  0.133967 -1.636095 -0.262377
# 29    Edge defects - edge cracks, FS  -0.734816 -1.386285 -0.130105 -1.317255
# 30     Tare weight (weight) exceeded  -1.816922 -1.386285 -0.118842 -0.262377
# 31     Tare weight (weight) exceeded  -0.633118 -0.011506 -0.130105  1.160347
# 32  Longitudinal or transverse seams  -1.777567 -1.386285 -0.130105  1.160347
# 33     Tare weight (weight) exceeded   0.641936  0.133967  1.399913  1.160347
# 34    Edge defects - edge cracks, FS   1.077287  0.133967 -0.118842 -0.262377
# 35  Longitudinal or transverse seams  -0.787058  1.571386  1.399913 -1.317255
# 36    Edge defects - edge cracks, FS   0.861701  1.571386 -1.636095  0.908305
# 37    Edge defects - edge cracks, FS  -1.502077  1.571386 -0.130105 -1.317255
# 38  Longitudinal or transverse seams  -0.759543 -0.011506 -0.130105  0.908305
# 39  Longitudinal or transverse seams  -0.855321 -1.386285 -1.636095  1.160347
# 40  Longitudinal or transverse seams  -0.081094  0.133967 -1.636095 -0.262377
# 41    Edge defects - edge cracks, FS  -0.158064  0.133967 -0.118842 -0.262377
# 42     Tare weight (weight) exceeded   0.394309  0.133967 -0.118842  0.908305
# 43  Longitudinal or transverse seams  -0.685012 -0.011506  1.399913  0.908305
# 44    Edge defects - edge cracks, FS  -0.389322  0.133967  1.399913  0.908305
# 45  Longitudinal or transverse seams   1.197791 -1.386285 -0.118842 -0.262377
# 46  Longitudinal or transverse seams  -1.142652  1.571386 -0.118842  0.908305
# 47     Tare weight (weight) exceeded  -0.502164  1.571386  1.399913 -1.317255
# 48     Tare weight (weight) exceeded   1.422084  0.133967  1.399913  1.160347
# 49     Tare weight (weight) exceeded  -0.759195 -1.386285 -1.636095 -1.317255
#
#           AG        AI
# 0   0.913666 -0.113961
# 1   0.913666 -1.025645
# 2  -1.384809  0.683763
# 3  -1.384809  0.797724
# 4  -1.384809 -1.595448
# 5  -1.384809  0.455842
# 6   0.762432  1.253566
# 7   0.762432 -1.481487
# 8  -1.384809  1.025645
# 9   0.762432  1.367527
# 10 -1.384809  0.683763
# 11  0.762432 -0.911685
# 12  0.913666 -0.569803
# 13 -1.384809 -0.227921
# 14 -0.406352  0.797724
# 15 -0.406352  0.683763
# 16  0.762432  1.481487
# 17  0.913666  1.253566
# 18 -1.384809  1.025645
# 19  0.913666  0.000000
# 20 -0.406352  1.481487
# 21  0.913666 -0.455842
# 22  0.762432 -1.595448
# 23 -1.384809 -0.455842
# 24  0.913666  0.227921
# 25  0.913666  1.139606
# 26  0.762432  0.455842
# 27 -0.406352 -1.481487
# 28 -0.406352 -0.683763
# 29 -1.384809  1.595448
# 30 -1.384809 -0.227921
# 31 -0.406352 -0.797724
# 32  0.762432 -1.595448
# 33  0.913666 -0.113961
# 34  0.913666 -1.139606
# 35 -1.384809 -0.911685
# 36  0.913666 -0.113961
# 37  0.762432  0.341882
# 38  0.913666  1.367527
# 39 -1.384809  0.455842
# 40  0.762432  1.709409
# 41  0.913666  0.911685
# 42  0.913666 -0.455842
# 43  0.762432 -1.595448
# 44  0.913666  0.341882
# 45 -1.384809  0.000000
# 46 -0.406352 -1.139606
# 47 -1.384809 -1.481487
# 48  0.762432 -1.025645
# 49  0.762432 -0.341882

# %%
# Checking for missing values in supplier_data_2

supplier_data_2.isna().sum()
# Out:
# Material       0
# Description    0
# Article ID     0
# Weight (kg)    0
# Quantity       0
# Reserved       0
# dtype: int64

# %%
# Renaming columns in supplier_data_2 for consistency

rename_cols_supplier_data_2 = {
    "Article ID": "Article_ID",
    "Weight (kg)": "Weight_kg",
}

# %%
supplier_data_2.rename(columns=rename_cols_supplier_data_2, inplace=True)
supplier_data_2['Article_ID'] = supplier_data_2['Article_ID'].astype(str)

# %%
# Descriptive statistics of supplier_data_2

supplier_data_2.describe()
# Out:
#           Weight_kg   Quantity
# count     50.000000  50.000000
# mean   16307.520000  57.920000
# std     5669.798014  25.197052
# min     5302.000000  10.000000
# 25%    11367.750000  33.250000
# 50%    16660.000000  62.000000
# 75%    21278.000000  74.500000
# max    24951.000000  98.000000

# %%
# Standardizing numerical columns in supplier_data_2

supplier_data_2 = supplier_data_2.apply(
    lambda x: StandardScaler().fit_transform(x.values.reshape(-1, 1)).flatten() 
    if x.dtype != "object" else x
)

# %%
supplier_data_2.to_csv('./data/cleaned_supplier_data_2.csv', index=False)
supplier_data_1.to_csv('./data/cleaned_supplier_data_1.csv', index=False)

# %% [markdown]
# - Koining both datasets on the `Description` column.

# %%
# Join on multiple columns: Description, Weight_kg, and Quantity

supplier_1_indexed = supplier_data_1.set_index(['Description'])
supplier_2_indexed = supplier_data_2.set_index(['Description'])
inventory_dataset = supplier_2_indexed.join(supplier_1_indexed, how='outer', lsuffix='_s2', rsuffix='_s1')

# %%
# Checking the column types in the merged dataset

inventory_dataset_num_columns = inventory_dataset.select_dtypes(include=['float64', 'int64']).columns
inventory_dataset_obj_columns = inventory_dataset.select_dtypes(include=['object']).columns

# %%
# Handling missing values in the merged dataset

inventory_dataset[inventory_dataset_num_columns] = inventory_dataset[inventory_dataset_num_columns].fillna(
    inventory_dataset[inventory_dataset_num_columns].mean()
)
inventory_dataset[inventory_dataset_obj_columns] = inventory_dataset[inventory_dataset_obj_columns].fillna(
    "Unknown"
)

# %% [markdown]
# - Saving the `inventory_dataset` as `inventory_dataset.csv`.

# %%
# Saving the cleaned, merged dataset to a CSV file

inventory_dataset.to_csv('inventory_dataset.csv', index=False)
