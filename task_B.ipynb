# %% [markdown]
# # Scenario B

# %%
import pandas as pd
import numpy as np

# %%
rfq_data = pd.read_csv('./data/rfq.csv')
reference_prop_data = pd.read_csv('./data/reference_properties.tsv', sep='\t')

# %%
rfq_data.isna().sum()
# Out:
# id                         0
# grade                     59
# grade_suffix            1000
# coating                  682
# finish                   335
# surface_type             865
# surface_protection       713
# form                      73
# thickness_min            167
# thickness_max            166
# width_min                461
# width_max                348
# length_min               869
# height_min               868
# height_max               998
# weight_min               607
# weight_max               369
# inner_diameter_min       823
# inner_diameter_max       822
# outer_diameter_min       977
# outer_diameter_max       980
# yield_strength_min       964
# yield_strength_max       984
# tensile_strength_min     951
# tensile_strength_max     949
# dtype: int64

# %%
reference_prop_data.isna().sum()
# Out:
# Grade/Material                         0
# UNS_No                               175
# Steel_No                             175
# Standards                              0
# Carbon (C)                             0
# Manganese (Mn)                         0
# Silicon (Si)                          41
# Sulfur (S)                            12
# Phosphorus (P)                        12
# Chromium (Cr)                        133
# Nickel (Ni)                          159
# Molybdenum (Mo)                      145
# Vanadium (V)                         150
# Tungsten (W)                         175
# Cobalt (Co)                          175
# Copper (Cu)                          174
# Aluminum (Al)                         81
# Titanium (Ti)                        146
# Niobium (Nb)                         149
# Boron (B)                            167
# Nitrogen (N)                         158
# Tensile strength (Rm)                  0
# Yield strength (Re or Rp0.2)          11
# Elongation (A%)                       21
# Reduction of area (Z%)               175
# Hardness (HB, HV, HRC)               142
# Impact toughness (Charpy V-notch)    159
# Fatigue limit                        175
# Creep resistance                     175
# Source_Pages                           0
# Application                            0
# Category                               0
# Nb + V + Ti (Others)                 167
# Coating                              155
# dtype: int64

# %%
rfq_drop_cols = [col for col in rfq_data.columns if rfq_data[col].isna().sum() > 0.6 * len(rfq_data)]
reference_prop_data_drop_cols = [col for col in reference_prop_data.columns if reference_prop_data[col].isna().sum() > 0.6 * len(reference_prop_data)]

rfq_data_cleaned = rfq_data.drop(columns=rfq_drop_cols)
reference_prop_data_cleaned = reference_prop_data.drop(columns=reference_prop_data_drop_cols)

# %% [markdown]
# ### Task B.1

# %%
# Capitalize first letter of each column name

rfq_data_cleaned.columns = rfq_data_cleaned.columns.str.capitalize()
reference_prop_data_cleaned.columns = reference_prop_data_cleaned.columns.str.capitalize()

# %% [markdown]
# - After capitilizing every first letter of each column in both datasets to maintain a consistent naming standard, we will be renaming the `Grade/material` column to `Grade` for joining both of the tables.

# %%
# Rename 'Grade/material' to 'Grade' for easier merging

reference_prop_data_cleaned.rename(columns={'Grade/material': 'Grade'}, inplace=True)

# %%
reference_prop_data_cleaned
# Out:
#         Grade                 Standards Carbon (c) Manganese (mn)  \
# 0      S235JR           EN 10025-2:2019      ≤0.17          ≤1.40
# 1      S275JR           EN 10025-2:2019      ≤0.21          ≤1.50
# 2      S355JR           EN 10025-2:2019      ≤0.24          ≤1.60
# 3       S420M           EN 10025-3:2019      ≤0.20      1.00-1.70
# 4       S460M           EN 10025-3:2019      ≤0.20      1.00-1.70
# ..        ...                       ...        ...            ...
# 170  HX300LAD  Automotive specification      ≤0.12      0.60-1.00
# 171  HX340LAD  Automotive specification      ≤0.12      0.70-1.20
# 172     HX380  Automotive specification      ≤0.12      0.70-1.40
# 173     HX420  Automotive specification      ≤0.12      0.70-1.60
# 174  HX420LAD  Automotive specification      ≤0.12      0.70-1.60
#
#     Silicon (si) Sulfur (s) Phosphorus (p) Aluminum (al)  \
# 0          ≤0.40     ≤0.035         ≤0.035           NaN
# 1          ≤0.40     ≤0.035         ≤0.035           NaN
# 2          ≤0.55     ≤0.035         ≤0.035           NaN
# 3          ≤0.50     ≤0.025         ≤0.030           NaN
# 4          ≤0.50     ≤0.025         ≤0.030           NaN
# ..           ...        ...            ...           ...
# 170        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 171        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 172        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 173        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 174        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
#
#     Tensile strength (rm) Yield strength (re or rp0.2) Elongation (a%)  \
# 0             360-510 MPa                     ≥235 MPa            ≥26%
# 1             410-560 MPa                     ≥275 MPa            ≥23%
# 2             470-630 MPa                     ≥355 MPa            ≥22%
# 3             520-680 MPa                     ≥420 MPa            ≥19%
# 4             540-720 MPa                     ≥460 MPa            ≥17%
# ..                    ...                          ...             ...
# 170           380-480 MPa                     ≥300 MPa            ≥27%
# 171           410-510 MPa                     ≥340 MPa            ≥26%
# 172           450-580 MPa                     ≥380 MPa            ≥23%
# 173           480-620 MPa                     ≥420 MPa            ≥21%
# 174           480-620 MPa                     ≥420 MPa            ≥23%
#
#                 Source_pages                                Application  \
# 0    Standard Specifications                  General structural steels
# 1    Standard Specifications                  General structural steels
# 2    Standard Specifications                  General structural steels
# 3    Standard Specifications           Thermomechanically rolled steels
# 4    Standard Specifications           Thermomechanically rolled steels
# ..                       ...                                        ...
# 170  Standard Specifications  Automotive HSLA with improved drawability
# 171  Standard Specifications  Automotive HSLA with improved drawability
# 172  Standard Specifications             Automotive high strength steel
# 173  Standard Specifications             Automotive high strength steel
# 174  Standard Specifications  Automotive HSLA with improved drawability
#
#                 Category
# 0       Structural Steel
# 1       Structural Steel
# 2       Structural Steel
# 3    High Strength Steel
# 4    High Strength Steel
# ..                   ...
# 170           HSLA Steel
# 171           HSLA Steel
# 172           HSLA Steel
# 173           HSLA Steel
# 174           HSLA Steel
#
# [175 rows x 14 columns]

# %%
# Setting all the values in Grade column for both datasets to uppercase to maintain consistency

rfq_data_cleaned['Grade'] = rfq_data_cleaned['Grade'].str.upper()
reference_prop_data_cleaned['Grade'] = reference_prop_data_cleaned['Grade'].str.upper()

# %%
# Fill NaN values in Grade column in rfq dataset with 'Unknown'

rfq_data_cleaned['Grade'] = rfq_data_cleaned['Grade'].fillna('Unknown')

# %%
reference_prop_data_cleaned
# Out:
#         Grade                 Standards Carbon (c) Manganese (mn)  \
# 0      S235JR           EN 10025-2:2019      ≤0.17          ≤1.40
# 1      S275JR           EN 10025-2:2019      ≤0.21          ≤1.50
# 2      S355JR           EN 10025-2:2019      ≤0.24          ≤1.60
# 3       S420M           EN 10025-3:2019      ≤0.20      1.00-1.70
# 4       S460M           EN 10025-3:2019      ≤0.20      1.00-1.70
# ..        ...                       ...        ...            ...
# 170  HX300LAD  Automotive specification      ≤0.12      0.60-1.00
# 171  HX340LAD  Automotive specification      ≤0.12      0.70-1.20
# 172     HX380  Automotive specification      ≤0.12      0.70-1.40
# 173     HX420  Automotive specification      ≤0.12      0.70-1.60
# 174  HX420LAD  Automotive specification      ≤0.12      0.70-1.60
#
#     Silicon (si) Sulfur (s) Phosphorus (p) Aluminum (al)  \
# 0          ≤0.40     ≤0.035         ≤0.035           NaN
# 1          ≤0.40     ≤0.035         ≤0.035           NaN
# 2          ≤0.55     ≤0.035         ≤0.035           NaN
# 3          ≤0.50     ≤0.025         ≤0.030           NaN
# 4          ≤0.50     ≤0.025         ≤0.030           NaN
# ..           ...        ...            ...           ...
# 170        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 171        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 172        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 173        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
# 174        ≤0.50     ≤0.015         ≤0.025   0.015-0.070
#
#     Tensile strength (rm) Yield strength (re or rp0.2) Elongation (a%)  \
# 0             360-510 MPa                     ≥235 MPa            ≥26%
# 1             410-560 MPa                     ≥275 MPa            ≥23%
# 2             470-630 MPa                     ≥355 MPa            ≥22%
# 3             520-680 MPa                     ≥420 MPa            ≥19%
# 4             540-720 MPa                     ≥460 MPa            ≥17%
# ..                    ...                          ...             ...
# 170           380-480 MPa                     ≥300 MPa            ≥27%
# 171           410-510 MPa                     ≥340 MPa            ≥26%
# 172           450-580 MPa                     ≥380 MPa            ≥23%
# 173           480-620 MPa                     ≥420 MPa            ≥21%
# 174           480-620 MPa                     ≥420 MPa            ≥23%
#
#                 Source_pages                                Application  \
# 0    Standard Specifications                  General structural steels
# 1    Standard Specifications                  General structural steels
# 2    Standard Specifications                  General structural steels
# 3    Standard Specifications           Thermomechanically rolled steels
# 4    Standard Specifications           Thermomechanically rolled steels
# ..                       ...                                        ...
# 170  Standard Specifications  Automotive HSLA with improved drawability
# 171  Standard Specifications  Automotive HSLA with improved drawability
# 172  Standard Specifications             Automotive high strength steel
# 173  Standard Specifications             Automotive high strength steel
# 174  Standard Specifications  Automotive HSLA with improved drawability
#
#                 Category
# 0       Structural Steel
# 1       Structural Steel
# 2       Structural Steel
# 3    High Strength Steel
# 4    High Strength Steel
# ..                   ...
# 170           HSLA Steel
# 171           HSLA Steel
# 172           HSLA Steel
# 173           HSLA Steel
# 174           HSLA Steel
#
# [175 rows x 14 columns]

# %% [markdown]
# - Now, we will be parsing range strings into numeric min, max and mid values.

# %%
# Declaring the columns which have range values in reference properties dataset

elements_cols = [
    'Carbon (c)',
    'Manganese (mn)',
    'Silicon (si)',
    'Sulfur (s)',
    'Phosphorus (p)',
    'Aluminum (al)',
    'Elongation (a%)'
]
range_symbols = ['-', '≤', '<', '>', '≥', '%']

# %%
reference_prop_data_cleaned[elements_cols] = reference_prop_data_cleaned[elements_cols].fillna('Unknown')

# %%
# Creating min, max and mid columns for each of the elements columns

def create_min_max_mid(value: str):
    if any(element in value for element in range_symbols) and value != 'Unknown':
        if '-' in value:
            min_val, max_val = value.replace("MPa", '').replace('%', '').split('-')
            return float(min_val), float(max_val), (float(min_val) + float(max_val)) / 2
        elif '≤' in value or '<' in value:
            if '%' in value:
                value = value.replace('%', '')
                max_val = float(value.replace('≤', '').replace('<', ''))
                return None, max_val / 100, None
            else:
                value = value.replace("MPa", '').replace('≤', '').replace('<', '')
                max_val = float(value)
                return None, max_val, None
        elif '≥' in value or '>' in value:
            if '%' in value:
                value = value.replace('%', '')
                min_val = float(value.replace('≥', '').replace('>', ''))
                return min_val / 100, None, None
            else:
                value = value.replace("MPa", '').replace('≥', '').replace('>', '')
                min_val = float(value)
                return min_val, None, None
    else:
        return None, None, None
        
def create_min_max_mid_columns(df, cols):
    for col in cols:
        min_col = f'{col}_min'
        max_col = f'{col}_max'
        mid_col = f'{col}_mid'
        
        df[[min_col, max_col, mid_col]] = df[col].apply(lambda x: pd.Series(create_min_max_mid(x)))
    return df

# %%
# Creating min, max and mid columns for each of the elements columns in reference properties dataset

reference_prop_data_cleaned = create_min_max_mid_columns(reference_prop_data_cleaned, elements_cols)
reference_prop_data_cleaned.drop(columns=elements_cols, inplace=True)

# %% [markdown]
# - Joining both of the datasets with the `Grade` column.

# %%
# Merging both of the datasets with the `Grade` column.

merged_data = reference_prop_data_cleaned.merge(
    rfq_data_cleaned, 
    on='Grade', 
    how='right', 
    suffixes=('_ref', '_rfq')
)

# %%
merged_data.reset_index()
# Out:
#       index   Grade        Standards Tensile strength (rm)  \
# 0         0  S700MC  EN 10149-2:2013           750-950 MPa
# 1         1  S250GD    EN 10346:2015           330-510 MPa
# 2         2   DX51D    EN 10346:2015           270-500 MPa
# 3         3    S235  EN 10025-2:2019           360-510 MPa
# 4         4    S235  EN 10025-2:2019           360-510 MPa
# ...     ...     ...              ...                   ...
# 1000   1000   DX51D    EN 10346:2015           270-500 MPa
# 1001   1001    DD11    EN 10111:2008           270-410 MPa
# 1002   1002  S550MC  EN 10149-2:2013           600-760 MPa
# 1003   1003    DD11    EN 10111:2008           270-410 MPa
# 1004   1004    DD12    EN 10111:2008           270-410 MPa
#
#      Yield strength (re or rp0.2)             Source_pages  \
# 0                        ≥700 MPa  Standard Specifications
# 1                        ≥250 MPa  Standard Specifications
# 2                        ≤350 MPa  Standard Specifications
# 3                        ≥235 MPa  Standard Specifications
# 4                        ≥235 MPa  Standard Specifications
# ...                           ...                      ...
# 1000                     ≤350 MPa  Standard Specifications
# 1001                     ≤380 MPa  Standard Specifications
# 1002                     ≥550 MPa  Standard Specifications
# 1003                     ≤380 MPa  Standard Specifications
# 1004                     ≤280 MPa  Standard Specifications
#
#                                             Application            Category  \
# 0     Cold forming, automotive, high strength applic...  Microalloyed Steel
# 1                           Structural galvanized steel    Galvanized Steel
# 2                          Galvanized steel for forming    Galvanized Steel
# 3                              General structural steel    Structural Steel
# 4                              General structural steel    Structural Steel
# ...                                                 ...                 ...
# 1000                       Galvanized steel for forming    Galvanized Steel
# 1001                               General cold forming   Cold Rolled Steel
# 1002                    Cold forming microalloyed steel  Microalloyed Steel
# 1003                               General cold forming   Cold Rolled Steel
# 1004                              Drawing quality steel   Cold Rolled Steel
#
#       Carbon (c)_min  Carbon (c)_max  ...  Elongation (a%)_max  \
# 0                NaN            0.12  ...                  NaN
# 1                NaN            0.25  ...                  NaN
# 2                NaN            0.12  ...                  NaN
# 3                NaN            0.17  ...                  NaN
# 4                NaN            0.17  ...                  NaN
# ...              ...             ...  ...                  ...
# 1000             NaN            0.12  ...                  NaN
# 1001             NaN            0.12  ...                  NaN
# 1002             NaN            0.12  ...                  NaN
# 1003             NaN            0.12  ...                  NaN
# 1004             NaN            0.10  ...                  NaN
#
#       Elongation (a%)_mid                                    Id  \
# 0                     NaN  8aff426d-b8c0-43aa-ad26-835ef4de6129
# 1                     NaN  37e624be-b125-464f-85b6-1838530193ef
# 2                     NaN  b8257184-6307-46ab-b06e-d979336d1263
# 3                     NaN  63140d1f-dda8-40fe-8931-bcaba65d5772
# 4                     NaN  11cffc57-44be-4d79-bfd5-97482be566d3
# ...                   ...                                   ...
# 1000                  NaN  7a965ba4-be4e-4833-a723-1f98ed1f24ac
# 1001                  NaN  82fc492f-0adc-49bd-8458-69bb1f0f318e
# 1002                  NaN  d3db6f2f-6218-4612-8a63-c26d4ac69658
# 1003                  NaN  90b02a62-3da9-4648-948c-52627d086a50
# 1004                  NaN  26ea35b5-2ccf-4fdc-884f-50a7c3a000b8
#
#                             Finish         Form  Thickness_min  Thickness_max  \
# 0                            Oiled        Coils           6.00            6.0
# 1     Hot-dip zinc magnesium (+ZM)   Slit Coils           1.50            1.5
# 2      Hot-dip Galvanized (+Z/+GI)        Coils           0.40            0.4
# 3                              NaN  Round Tubes           1.50            1.5
# 4                              NaN  Round Tubes           1.50            1.5
# ...                            ...          ...            ...            ...
# 1000   Hot-dip Galvanized (+Z/+GI)        Coils           0.55            0.6
# 1001                    Hot Rolled        Coils            NaN            NaN
# 1002                    Hot Rolled        Coils           3.40            3.6
# 1003                    Hot Rolled        Coils           2.40            2.6
# 1004                    Hot Rolled        Coils           5.00            5.0
#
#       Width_min  Width_max  Weight_max
# 0         600.0     1520.0     25000.0
# 1         327.0      327.0         NaN
# 2        1000.0     1500.0         NaN
# 3           NaN        NaN     53800.0
# 4           NaN        NaN     14500.0
# ...         ...        ...         ...
# 1000        NaN        NaN         NaN
# 1001        NaN     1520.0     25000.0
# 1002        NaN     1520.0     35000.0
# 1003      600.0     1520.0     25000.0
# 1004        NaN        NaN     25000.0
#
# [1005 rows x 37 columns]

# %%
# Dropping columns with more than 60% NaN values

merged_data_drop_cols = [col for col in merged_data.columns if merged_data[col].isna().sum() > 0.6 * len(merged_data)]
merged_data_cleaned = merged_data.drop(columns=merged_data_drop_cols)

# %%
merged_data_obj_cols = merged_data.select_dtypes(include=['object']).columns
merged_data_num_cols = merged_data.select_dtypes(include=['number']).columns

# %%
# Imputing missing values in numerical columns with mean and categorical columns with 'Unknown'

merged_data[merged_data_num_cols] = merged_data[merged_data_num_cols].fillna(merged_data[merged_data_num_cols].mean())
merged_data[merged_data_obj_cols] = merged_data[merged_data_obj_cols].fillna('Unknown')
merged_data.drop_duplicates(inplace=True)

# %% [markdown]
# ### Task B.2
